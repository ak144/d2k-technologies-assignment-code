# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyarrow.parquet as pq
import os
from urllib.parse import urlparse

base_url = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet'
os.system(f"curl -O {base_url}")
path = urlparse(base_url).path
parquet_file_path = f"./{os.path.basename(path)}"
df = pq.ParquetFile(parquet_file_path)

# %%
print(table.head(10))
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
# 5         2  2018-11-28 16:25:49   2018-11-28 16:28:26              5.0
# 6         2  2018-11-28 16:29:37   2018-11-28 16:33:43              5.0
# 7         1  2019-01-01 00:21:28   2019-01-01 00:28:37              1.0
# 8         1  2019-01-01 00:32:01   2019-01-01 00:45:39              1.0
# 9         1  2019-01-01 00:57:32   2019-01-01 01:09:32              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# ...

# %%
table = table.to_pandas()

# %%
import pyarrow.parquet as pq

# %%
import pyarrow.parquet as pa
trips = pd.read_paraquet(table)
trips = trips.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 trips = pd.read_paraquet(table)
#       2 trips = trips.to_pandas()
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_paraquet'

# %%
import pyarrow.parquet as pa
import requests
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet"


query_parameters = {"format":"parquet"}

response = requests.get(url, params=query_parameters)

response.ok # True if status code is less than 400, otherwise False

response.status_code
with open("tripss.parquet", mode="wb") as file:    
  file.write(response.content)

# %%
table = pa.read_table("tripss.parquet")

# %%
table.to_csv(r"C:\Users\hp\Documents\trips.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 table.to_csv(r"C:\Users\hp\Documents\trips.csv", index=False)
#
# AttributeError: 'pyarrow.lib.Table' object has no attribute 'to_csv'

# %%
table.to_csv(r"C:\Users\hp\Documents\trips.csv", index=False)

# %%
table = table.to_pandas()

# %%
print(table.head(10))
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
# 5         2  2018-11-28 16:25:49   2018-11-28 16:28:26              5.0
# 6         2  2018-11-28 16:29:37   2018-11-28 16:33:43              5.0
# 7         1  2019-01-01 00:21:28   2019-01-01 00:28:37              1.0
# 8         1  2019-01-01 00:32:01   2019-01-01 00:45:39              1.0
# 9         1  2019-01-01 00:57:32   2019-01-01 01:09:32              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# ...

# %%
import numpy as np

# %%
bool_series = pd.isnull('tripss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 bool_series = pd.isnull('tripss')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
null_df = table.isnull()
print(null_df)
# Out:
#          VendorID  tpep_pickup_datetime  tpep_dropoff_datetime  \
# 0           False                 False                  False
# 1           False                 False                  False
# 2           False                 False                  False
# 3           False                 False                  False
# 4           False                 False                  False
# ...           ...                   ...                    ...
# 7696612     False                 False                  False
# 7696613     False                 False                  False
# 7696614     False                 False                  False
# 7696615     False                 False                  False
# 7696616     False                 False                  False
#
#          passenger_count  trip_distance  RatecodeID  store_and_fwd_flag  \
# 0                  False          False       False               False
# ...

# %%
table = table.dropna(axis=1)
print(table)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  trip_distance  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20           1.50
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59           2.60
# 2               2  2018-12-21 13:48:30   2018-12-21 13:52:40           0.00
# 3               2  2018-11-28 15:52:25   2018-11-28 15:55:45           0.00
# 4               2  2018-11-28 15:56:57   2018-11-28 15:58:33           0.00
# ...           ...                  ...                   ...            ...
# 7696612         2  2019-01-31 23:37:20   2019-02-01 00:10:43          10.24
# 7696613         2  2019-01-31 23:28:00   2019-01-31 23:50:50          12.43
# 7696614         2  2019-01-31 23:11:00   2019-01-31 23:46:00           9.14
# 7696615         2  2019-01-31 23:03:00   2019-01-31 23:14:00           0.00
# 7696616         2  2019-01-31 23:41:03   2019-02-01 00:19:16          12.30
#
# ...

# %%
print(table.head(10))
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  trip_distance  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20            1.5
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59            2.6
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40            0.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45            0.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33            0.0
# 5         2  2018-11-28 16:25:49   2018-11-28 16:28:26            0.0
# 6         2  2018-11-28 16:29:37   2018-11-28 16:33:43            0.0
# 7         1  2019-01-01 00:21:28   2019-01-01 00:28:37            1.3
# 8         1  2019-01-01 00:32:01   2019-01-01 00:45:39            3.7
# 9         1  2019-01-01 00:57:32   2019-01-01 01:09:32            2.1
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           151           239             1          7.0    0.5      0.5
# ...

# %%
table['time_duration']=table['tpep_dropoff_datetime']-table['tpep_pickup_datetime']

# %%
print(table['time_duration'])
# Out:
# 0         0 days 00:06:40
# 1         0 days 00:19:12
# 2         0 days 00:04:10
# 3         0 days 00:03:20
# 4         0 days 00:01:36
#                 ...
# 7696612   0 days 00:33:23
# 7696613   0 days 00:22:50
# 7696614   0 days 00:35:00
# 7696615   0 days 00:11:00
# 7696616   0 days 00:38:13
# Name: time_duration, Length: 7696617, dtype: timedelta64[ns]

# %%
import pandas as pd
table['time_duration']=(table['time_duration'])/pd.Timedelta(minutes=1)

# %%
print(table['time_duration'])
# Out:
# 0           6.666667
# 1          19.200000
# 2           4.166667
# 3           3.333333
# 4           1.600000
#              ...
# 7696612    33.383333
# 7696613    22.833333
# 7696614    35.000000
# 7696615    11.000000
# 7696616    38.216667
# Name: time_duration, Length: 7696617, dtype: float64

# %%
#distance covered in KM
table['trip_distance']=table['trip_distance']*1.6

# %%
print(table['trip_distance'])
# Out:
# 0           2.400
# 1           4.160
# 2           0.000
# 3           0.000
# 4           0.000
#             ...
# 7696612    16.384
# 7696613    19.888
# 7696614    14.624
# 7696615     0.000
# 7696616    19.680
# Name: trip_distance, Length: 7696617, dtype: float64

# %%
table['speed']=table['trip_distance']/table['time_duration']

# %%
#speed in KM Per minute
print(table['speed'])
# Out:
# 0          0.360000
# 1          0.216667
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 7696612    0.490784
# 7696613    0.871007
# 7696614    0.417829
# 7696615    0.000000
# 7696616    0.514959
# Name: speed, Length: 7696617, dtype: float64

# %%
#speed in KM Per hour
table['speed']=table['speed']*60

# %%
print(table['speed'])
# Out:
# 0          21.600000
# 1          13.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
#              ...
# 7696612    29.447029
# 7696613    52.260438
# 7696614    25.069714
# 7696615     0.000000
# 7696616    30.897514
# Name: speed, Length: 7696617, dtype: float64

# %%
arr=np.array(table['speed'])
average_speed=np.mean(arr,axis=0)

# %%
print(average_speed)
# Out:
# nan

# %%
table=table.dropna()

# %%
mean_speed =table['speed'].mean(skipna=True)

# %%
print(average_speed)
# Out:
# nan

# %%
import numpy as np
from itertools import groupby
NaN = np.nan
lst = table['speed']
[np.mean(list(g)) for k, g in groupby(lst, key=lambda x: x is not NaN) if k]
# [6.0, 5.0]
# Out:
# [inf]

# %%
#total trips
total_trips=len(table)
print(total_trips)
# Out:
# 7690473

# %%
from datetime import datetime
table['just_date']=pd.to_datetime(table['tpep_pickup_datetime'],utc=False)

# %%
print (table['just_date'])
# Out:
# 0         2019-01-01 00:46:40
# 1         2019-01-01 00:59:47
# 2         2018-12-21 13:48:30
# 3         2018-11-28 15:52:25
# 4         2018-11-28 15:56:57
#                   ...
# 7696612   2019-01-31 23:37:20
# 7696613   2019-01-31 23:28:00
# 7696614   2019-01-31 23:11:00
# 7696615   2019-01-31 23:03:00
# 7696616   2019-01-31 23:41:03
# Name: just_date, Length: 7690473, dtype: datetime64[ns]

# %%
table['just_date']=table['just_date'].dt.date

# %%
print (table['just_date'])
# Out:
# 0          2019-01-01
# 1          2019-01-01
# 2          2018-12-21
# 3          2018-11-28
# 4          2018-11-28
#               ...
# 7696612    2019-01-31
# 7696613    2019-01-31
# 7696614    2019-01-31
# 7696615    2019-01-31
# 7696616    2019-01-31
# Name: just_date, Length: 7690473, dtype: object

# %%
#average fare price for each day
grouped=table.groupby(['just_date','total_amount']).mean()

# %%
print(grouped)
# Out:
#                          VendorID  trip_distance  PULocationID  DOLocationID  \
# just_date  total_amount
# 2001-02-02 3.80               2.0          0.000         193.0         193.0
# 2003-01-01 0.00               2.0          0.000         264.0         193.0
# 2008-12-31 3.30               2.0          0.048         107.0         107.0
#            4.30               2.0          0.352         189.0         189.5
#            4.80               2.0          0.672         237.0         237.0
# ...                           ...            ...           ...           ...
# 2019-07-23 18.96              2.0          5.008         148.0         234.0
# 2019-08-13 22.80              2.0          8.592         114.0         181.0
# 2019-09-03 6.80               2.0          1.024         148.0          79.0
# 2088-01-24 5.30               2.0          1.008          41.0         166.0
#            15.30              2.0          6.480          24.0         162.0
#
# ...

# %%
#average fare per day 
total_days=table.groupby(['just_date'])['just_date'].count()
total_days=len(total_days)
total_amount=table[['total_amount']].sum()
average_fare_per_day =total_amount/total_days
print(average_fare_per_day)
# Out:
# total_amount    2.083489e+06
# dtype: float64

# %%
total_days=table.groupby(['just_date'])['just_date'].count()
total_days=len(total_days)
print(total_days)
# Out:
# 58

# %%
import sqlite3

# %%
con = sqlite3.connect("table.db")

# %%
cur = con.cursor()

# %%
table ='''CREATE TABLE tripsss(VendorID,
tpep_pickup_datetime,
tpep_dropoff_datetime,
passenger_count,
trip_distance,
RatecodeID,
store_and_fwd_flag,
PULocationID,
DOLocationID,
payment_type,
fare_amount,
extra,
mta_tax,
tip_amount,
tolls_amount,
improvement_surcharge,
total_amount,
congestion_surcharge,
airport_fee);'''

# %%
cur.execute(table)

# %%
file = open(r"C:\Users\hp\Documents\trips.csv")

# %%
import csv
contents = csv.reader(file)

# %%
insert_records = "INSERT INTO tripsss(VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,RatecodeID,store_and_fwd_flag,PULocationID,DOLocationID,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount,congestion_surcharge,airport_fee) VALUES(?, ?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)"

# %%
cur.executemany(insert_records, contents)

# %%
peak_hours = cur.execute("SELECT peak_HOUR,MAX(MYCOUNT)FROM (select strftime('%H',tpep_pickup_datetime) AS peak_hour,COUNT(tpep_pickup_datetime) AS MYCOUNT from Tripsss  GROUP BY peak_hour)");

# %%
peak_hours.fetchall()
#peak time is between 6:00 to 7:00
# Out:
# [('18', 515390)]

# %%
QUERY = cur.execute("select typeof(tpep_pickup_datetime) from tripsss");

# %%
QUERY.fetchall()
# Out:
# [('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
#  ('text',),
# ...

# %%
#passenger count vs trip fare 

QUERY2 =cur.execute("select passenger_count,fare_amount from tripsss group by passenger_count")

# %%
QUERY2.fetchall()
# Out:
# [('', '12.24'),
#  ('0.0', '2.5'),
#  ('1.0', '7.0'),
#  ('2.0', '10.0'),
#  ('3.0', '4.5'),
#  ('4.0', '8.0'),
#  ('5.0', '3.5'),
#  ('6.0', '4.0'),
#  ('7.0', '70.0'),
#  ('8.0', '8.0'),
#  ('9.0', '9.8')]

# %%
import matplotlib.pyplot as plt

# %%
table.groupby(['passenger_count']).sum().plot.bar(xlabel=,ylabel='fare_amount')
x
# Out:
# <AxesSubplot:xlabel='passenger_count', ylabel='fare_amount'>
